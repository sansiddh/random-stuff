# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, PercentFormatter

# %%
fig, ax = plt.subplots(figsize=(12, 8))

ax.plot([0, 30, 60, 90, 120, 250, 500], [0, 50, 100, 200, 300, 400, 500], label='Indian AQI')
ax.plot([0, 12, 35.4, 55.4, 150.4, 250.4, 500.4], [0, 50, 100, 150, 200, 300, 500], label='US AQI')
ax.grid()
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(12, 8))

ax.plot([0, 50, 100, 250, 350, 430, 600], [0, 50, 100, 200, 300, 400, 500], label='Indian AQI')
ax.plot([0, 54, 154, 254, 354, 424, 604], [0, 50, 100, 150, 200, 300, 500], label='US AQI')
ax.grid()
ax.legend()
